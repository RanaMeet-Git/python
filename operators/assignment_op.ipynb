# %%
x=10
print(x)
# Out:
# 10

# %%
x=5
x+=1
print(x)
# Out:
# 6

# %%
x=5
x-=1
print(x)
# Out:
# 4

# %%
x = 6
x *= 4

print(x)
# Out:
# 24

# %%
x = 20
x /= 4

print(x)
# Out:
# 5.0

# %%
x = 17
x %= 5

print(x)
# Out:
# 2

# %%
x = 3
x **= 2

print(x)
# Out:
# 9

# %%
x = 17
x //= 5

print(x)
# Out:
# 3

# %%
salary = 25000

salary += 5000      # Add bonus
salary -= 2000      # Deduct expenses
salary *= 2         # Double the amount

print("Final Salary:", salary)
# Out:
# Final Salary: 56000
