# %%
#and operator
a = 10
b = 6

print(a & b)
# Out:
# 2

# %%
#or
a = 10
b = 6

print(a | b)
# Out:
# 14

# %%
#xor
a = 10
b = 6

print(a ^ b)
# Out:
# 12

# %%
#not
a = 10

print(~a)
# Out:
# -11

# %%
#left shift
a = 5

print(a << 2)
# Out:
# 20

# %%
#right shift
a=20
print(a>>2)
# Out:
# 5
