# %% [markdown]
# Data Types

# %%
a=[10,20.3,True,False,"fission labs"]
for i in range(len(a)):
    print(a[i],type(a[i]))
# Out:
# 10 <class 'int'>
# 20.3 <class 'float'>
# True <class 'bool'>
# False <class 'bool'>
# fission labs <class 'str'>

# %% [markdown]
# impicit type convesion

# %%
a=10
b=10.5
c=a+b
print(c,type(c))
# Out:
# 20.5 <class 'float'>

# %%
a="fission_labs"
b=a*3
print(b,type(b))
# Out:
# fission_labsfission_labsfission_labs <class 'str'>

# %% [markdown]
# explicit type conversion

# %%
a=10
b=float(a)
print(b,type(b))
# Out:
# 10.0 <class 'float'>

# %%
a=10.5
b=int(a)
print(b,type(b))
# Out:
# 10 <class 'int'>

# %%
a=10
b=str(a)
print(b,type(b))
# Out:
# 10 <class 'str'>

# %% [markdown]
# OPERATORS

# %%
#arthemetic operators
a=int(input("enter the number"))
b=int(input("enter the number"))
print(a+b,"Addition")
print(a-b,"subtration")
print(a/b,"Divison")
print(a//b,"Floor division")
print(a*b,"multiplication")
print(a**b,"exponetiation")
print(a%b,"mdoules")
# Out:
# 8 Addition
# 2 subtration
# 1.6666666666666667 Divison
# 1 Floor division
# 15 multiplication
# 125 exponetiation
# 2 mdoules

# %% [markdown]
# comparison operators

# %%
a=int(input("enter the number"))
b=int(input("enter the number"))
print(a==b)
print(a!=b)
print(a>b)
print(a<b)
print(a>=b)
print(a<=b)
# Out:
# False
# True
# True
# False
# True
# False
