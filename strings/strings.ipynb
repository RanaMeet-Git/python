# %%
s='fission labs'

print(s.upper())
print(s.lower())
print(s.title())
print(s.capitalize())
print(s.strip())
print(s.lstrip())
print(s.replace("fission",'vission'))
print(s.split())
# Out:
# FISSION LABS
# fission labs
# Fission Labs
# Fission labs
# fission labs
# fission labs
# vission labs
# ['fission', 'labs']

# %%
print(s.find("s"))
print(s.index("i"))
print(s.count("s"))
print(s.isalpha())
# Out:
# 2
# 1
# 3
# False

# %%
print(s[0])

for i in s:
    print(i)
# Out:
# f
# f
# i
# s
# s
# i
# o
# n
#
# l
# a
# b
# s

# %%
for i in range(len(s)):
    print(s[i],i)
# Out:
# f 0
# i 1
# s 2
# s 3
# i 4
# o 5
# n 6
#   7
# l 8
# a 9
# b 10
# s 11

# %%
print(s[0:len(s):2])
print(s[::-1])
# Out:
# fsinlb
# sbal noissif
