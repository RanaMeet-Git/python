# %%
s='fission labs'

print(s.upper())
print(s.lower())
print(s.title())
print(s.capitalize())
print(s.strip())
print(s.lstrip())
print(s.replace("fission",'vission'))
print(s.split())
# Out:
# FISSION LABS
# fission labs
# Fission Labs
# Fission labs
# fission labs
# fission labs
# vission labs
# ['fission', 'labs']

# %%
print(s.find("s"))
print(s.index("i"))
print(s.count("s"))
print(s.isalpha())
# Out:
# 2
# 1
# 3
# False
