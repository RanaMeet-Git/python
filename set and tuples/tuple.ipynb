# %%
empty_tuple = ()

print(empty_tuple)
# Out:
# ()

# %%
fruits = ("Apple", "Mango", "Orange")

print(fruits)
# Out:
# ('Apple', 'Mango', 'Orange')

# %%
data = (10, "Python", 3.14, True)

print(data)
# Out:
# (10, 'Python', 3.14, True)

# %%
colors = ("Red", "Green", "Blue")

print(colors[0])
print(colors[1])
print(colors[2])
print(colors[-2])
# Out:
# Red
# Green
# Blue
# Green

# %%
numbers = (10, 20, 30, 40, 50)

print(numbers[1:4])
# Out:
# (20, 30, 40)

# %%
fruits = ("Apple", "Mango", "Orange")

for fruit in fruits:
    print(fruit)
# Out:
# Apple
# Mango
# Orange

# %%
t1 = (1, 2, 3)
t2 = (4, 5, 6)

result = t1 + t2

print(result)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
t = ("Python","fission")

print(t * 3)
# Out:
# ('Python', 'fission', 'Python', 'fission', 'Python', 'fission')

# %%
t = ("Python","fission")
list_from_tuple = list(t)
print(list_from_tuple)
# Out:
# ['Python', 'fission']

# %%
numbers = (10, 20, 10, 30, 10)

print(numbers.count(10))
# Out:
# 3

# %%
fruits = ("Apple", "Mango", "Orange")

print(fruits.index("Mango"))
# Out:
# 1

# %%
student = ("Rana", 22, "Python")

name, age, course = student

print(name)
print(age)
print(course)
# Out:
# Rana
# 22
# Python

# %%
student = (
    ("Rana", 22),
    ("Rahul", 25),
    ("Priya", 21)
)

print(student[1])
print(student[1][0])
# Out:
# ('Rahul', 25)
# Rahul

# %%
numbers = (10, 20, 30)

numbers[0] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 3
#       1 numbers = (10, 20, 30)
#       2
# ----> 3 numbers[0] = 100
#
# TypeError: 'tuple' object does not support item assignment
